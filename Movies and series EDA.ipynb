# %% [markdown]
# ## Import Dataset

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\Rohan\\Desktop\\Netflix Dataset Latest 2021(1).csv") 
df
# Out:
#                                           Title  \
# 0                              Lets Fight Ghost
# 1                           HOW TO BUILD A GIRL
# 2                              The Con-Heartist
# 3                                  Gleboka woda
# 4                                 Only a Mother
# ...                                         ...
# 9420                             13 Going on 30
# 9421                                   LIFE 2.0
# 9422                              Brand New Day
# 9423                Daniel Arends: Blessuretijd
# 9424  DreamWorks Happy Holidays from Madagascar
#
#                                        Genre  \
# 0     Crime, Drama, Fantasy, Horror, Romance
# 1                                     Comedy
# 2                            Comedy, Romance
# 3                                      Drama
# 4                                      Drama
# ...                                      ...
# 9420                Comedy, Fantasy, Romance
# ...

# %% [markdown]
# ## Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9425 entries, 0 to 9424
# Data columns (total 31 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9425 non-null   object
#  1   Genre                  9400 non-null   object
#  2   Tags                   9389 non-null   object
#  3   Languages              9255 non-null   object
#  4   Series or Movie        9425 non-null   object
#  5   Hidden Gem Score       9415 non-null   float64
#  6   Country Availability   9414 non-null   object
#  7   Runtime                9424 non-null   object
#  8   Director               7120 non-null   object
#  9   Writer                 7615 non-null   object
#  10  Actors                 9314 non-null   object
#  11  View Rating            6827 non-null   object
#  12  IMDb Score             9417 non-null   float64
#  13  Rotten Tomatoes Score  5445 non-null   float64
# ...

# %% [markdown]
# ## Statistical Summary

# %%
df.describe()
# Out:
#        Hidden Gem Score   IMDb Score  Rotten Tomatoes Score  Metacritic Score  \
# count       9415.000000  9417.000000            5445.000000       4082.000000
# mean           5.540733     6.955517              64.691276         58.113425
# std            2.447462     0.899681              25.269466         17.143187
# min            0.600000     1.600000               0.000000          6.000000
# 25%            3.400000     6.500000              49.000000         46.000000
# 50%            5.300000     7.000000              70.000000         59.000000
# 75%            8.100000     7.500000              85.000000         71.000000
# max            9.800000     9.700000             100.000000        100.000000
#
#        Awards Received  Awards Nominated For    IMDb Votes  Unnamed: 29  \
# count      5226.000000           6376.000000  9.415000e+03          0.0
# mean          9.735936             16.035602  6.014725e+04          NaN
# ...

# %% [markdown]
# ## Remove Unnecessary Columns

# %%
df.drop(['Tags','Languages' ,'Country Availability', 'Writer','Actors','View Rating','Netflix Release Date', 'Production House','Netflix Link','IMDb Link',
         'Summary','Image','Poster','TMDb Trailer','Trailer Site'] , axis=1, inplace=True)

# %%
df
# Out:
#                                           Title  \
# 0                              Lets Fight Ghost
# 1                           HOW TO BUILD A GIRL
# 2                              The Con-Heartist
# 3                                  Gleboka woda
# 4                                 Only a Mother
# ...                                         ...
# 9420                             13 Going on 30
# 9421                                   LIFE 2.0
# 9422                              Brand New Day
# 9423                Daniel Arends: Blessuretijd
# 9424  DreamWorks Happy Holidays from Madagascar
#
#                                        Genre Series or Movie  \
# 0     Crime, Drama, Fantasy, Horror, Romance          Series
# 1                                     Comedy           Movie
# 2                            Comedy, Romance           Movie
# 3                                      Drama          Series
# 4                                      Drama           Movie
# ...

# %%
df.drop(['Unnamed: 29','Unnamed: 30'],axis=1,inplace=True)

# %%
df
# Out:
#                                           Title  \
# 0                              Lets Fight Ghost
# 1                           HOW TO BUILD A GIRL
# 2                              The Con-Heartist
# 3                                  Gleboka woda
# 4                                 Only a Mother
# ...                                         ...
# 9420                             13 Going on 30
# 9421                                   LIFE 2.0
# 9422                              Brand New Day
# 9423                Daniel Arends: Blessuretijd
# 9424  DreamWorks Happy Holidays from Madagascar
#
#                                        Genre Series or Movie  \
# 0     Crime, Drama, Fantasy, Horror, Romance          Series
# 1                                     Comedy           Movie
# 2                            Comedy, Romance           Movie
# 3                                      Drama          Series
# 4                                      Drama           Movie
# ...

# %% [markdown]
# ## Renaming Columns

# %%
df.rename(columns={'Series or Movie': 'Type'}, inplace=True)

# %%
df
# Out:
#                                           Title  \
# 0                              Lets Fight Ghost
# 1                           HOW TO BUILD A GIRL
# 2                              The Con-Heartist
# 3                                  Gleboka woda
# 4                                 Only a Mother
# ...                                         ...
# 9420                             13 Going on 30
# 9421                                   LIFE 2.0
# 9422                              Brand New Day
# 9423                Daniel Arends: Blessuretijd
# 9424  DreamWorks Happy Holidays from Madagascar
#
#                                        Genre    Type  Hidden Gem Score  \
# 0     Crime, Drama, Fantasy, Horror, Romance  Series               4.3
# 1                                     Comedy   Movie               7.0
# 2                            Comedy, Romance   Movie               8.6
# 3                                      Drama  Series               8.7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9425 entries, 0 to 9424
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9425 non-null   object
#  1   Genre                  9400 non-null   object
#  2   Type                   9425 non-null   object
#  3   Hidden Gem Score       9415 non-null   float64
#  4   Runtime                9424 non-null   object
#  5   Director               7120 non-null   object
#  6   IMDb Score             9417 non-null   float64
#  7   Rotten Tomatoes Score  5445 non-null   float64
#  8   Metacritic Score       4082 non-null   float64
#  9   Awards Received        5226 non-null   float64
#  10  Awards Nominated For   6376 non-null   float64
#  11  Boxoffice              3754 non-null   object
#  12  Release Date           9217 non-null   object
#  13  IMDb Votes             9415 non-null   float64
# dtypes: float64(7), object(7)
# ...

# %%
df.drop(['Director'],axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9425 entries, 0 to 9424
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9425 non-null   object
#  1   Genre                  9400 non-null   object
#  2   Type                   9425 non-null   object
#  3   Hidden Gem Score       9415 non-null   float64
#  4   Runtime                9424 non-null   object
#  5   IMDb Score             9417 non-null   float64
#  6   Rotten Tomatoes Score  5445 non-null   float64
#  7   Metacritic Score       4082 non-null   float64
#  8   Awards Received        5226 non-null   float64
#  9   Awards Nominated For   6376 non-null   float64
#  10  Boxoffice              3754 non-null   object
#  11  Release Date           9217 non-null   object
#  12  IMDb Votes             9415 non-null   float64
# dtypes: float64(7), object(6)
# memory usage: 957.4+ KB

# %%
df.isnull().sum()
# Out:
# Title                       0
# Genre                      25
# Type                        0
# Hidden Gem Score           10
# Runtime                     1
# IMDb Score                  8
# Rotten Tomatoes Score    3980
# Metacritic Score         5343
# Awards Received          4199
# Awards Nominated For     3049
# Boxoffice                5671
# Release Date              208
# IMDb Votes                 10
# dtype: int64

# %% [markdown]
# ## Handling Missing Values

# %%
df.fillna({ 'Rotten Tomatoes Score':'Not Rated','Metacritic Score':'Not Rated', 'Metacritic Score':0,'Awards Received':0,'Awards Nominated For':0, 'Boxoffice': 'Not Disclosed' , 'IMDb Votes': 0,'Hidden Gem Score':0 },inplace=True)

# %%
df
# Out:
#                                           Title  \
# 0                              Lets Fight Ghost
# 1                           HOW TO BUILD A GIRL
# 2                              The Con-Heartist
# 3                                  Gleboka woda
# 4                                 Only a Mother
# ...                                         ...
# 9420                             13 Going on 30
# 9421                                   LIFE 2.0
# 9422                              Brand New Day
# 9423                Daniel Arends: Blessuretijd
# 9424  DreamWorks Happy Holidays from Madagascar
#
#                                        Genre    Type  Hidden Gem Score  \
# 0     Crime, Drama, Fantasy, Horror, Romance  Series               4.3
# 1                                     Comedy   Movie               7.0
# 2                            Comedy, Romance   Movie               8.6
# 3                                      Drama  Series               8.7
# ...

# %%
df.isnull().sum()
# Out:
# Title                      0
# Genre                     25
# Type                       0
# Hidden Gem Score           0
# Runtime                    1
# IMDb Score                 8
# Rotten Tomatoes Score      0
# Metacritic Score           0
# Awards Received            0
# Awards Nominated For       0
# Boxoffice                  0
# Release Date             208
# IMDb Votes                 0
# dtype: int64

# %%
df.dropna()
# Out:
#                             Title                                   Genre  \
# 0                Lets Fight Ghost  Crime, Drama, Fantasy, Horror, Romance
# 1             HOW TO BUILD A GIRL                                  Comedy
# 2                The Con-Heartist                         Comedy, Romance
# 3                    Gleboka woda                                   Drama
# 4                   Only a Mother                                   Drama
# ...                           ...                                     ...
# 9419       District 13: Ultimatum                 Action, Crime, Thriller
# 9420               13 Going on 30                Comedy, Fantasy, Romance
# 9421                     LIFE 2.0                             Documentary
# 9422                Brand New Day                      Documentary, Music
# 9423  Daniel Arends: Blessuretijd                                  Comedy
#
#         Type  Hidden Gem Score       Runtime  IMDb Score  \
# ...

# %%
df.isnull().sum()
# Out:
# Title                      0
# Genre                     25
# Type                       0
# Hidden Gem Score           0
# Runtime                    1
# IMDb Score                 8
# Rotten Tomatoes Score      0
# Metacritic Score           0
# Awards Received            0
# Awards Nominated For       0
# Boxoffice                  0
# Release Date             208
# IMDb Votes                 0
# dtype: int64

# %%
df['Rotten Tomatoes Score']=pd.to_numeric(df['Rotten Tomatoes Score'],errors='coerce')

# %%
df4=df

# %% [markdown]
# # EDA(EXPLORATORY DATA ANALYSYS)

# %% [markdown]
# ## Exploading Genre columns for better analysys

# %%
df4['Genre'] = df4['Genre'].str.split(', ') 
df4= df4.explode('Genre')

# %%
df4.head()
# Out:
#               Title    Genre    Type  Hidden Gem Score       Runtime  \
# 0  Lets Fight Ghost    Crime  Series               4.3  < 30 minutes
# 0  Lets Fight Ghost    Drama  Series               4.3  < 30 minutes
# 0  Lets Fight Ghost  Fantasy  Series               4.3  < 30 minutes
# 0  Lets Fight Ghost   Horror  Series               4.3  < 30 minutes
# 0  Lets Fight Ghost  Romance  Series               4.3  < 30 minutes
#
#    IMDb Score  Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0         7.9                   98.0              82.0             74.0
# 0         7.9                   98.0              82.0             74.0
# 0         7.9                   98.0              82.0             74.0
# 0         7.9                   98.0              82.0             74.0
# 0         7.9                   98.0              82.0             74.0
#
#    Awards Nominated For   Boxoffice Release Date  IMDb Votes
# ...

# %%
df5=df4.reset_index(drop=True)

# %%
df5
# Out:
#                                            Title      Genre    Type  \
# 0                               Lets Fight Ghost      Crime  Series
# 1                               Lets Fight Ghost      Drama  Series
# 2                               Lets Fight Ghost    Fantasy  Series
# 3                               Lets Fight Ghost     Horror  Series
# 4                               Lets Fight Ghost    Romance  Series
# ...                                          ...        ...     ...
# 26214                              Brand New Day      Music   Movie
# 26215                Daniel Arends: Blessuretijd     Comedy   Movie
# 26216  DreamWorks Happy Holidays from Madagascar  Animation  Series
# 26217  DreamWorks Happy Holidays from Madagascar     Comedy  Series
# 26218  DreamWorks Happy Holidays from Madagascar     Family  Series
#
#        Hidden Gem Score       Runtime  IMDb Score  Rotten Tomatoes Score  \
# 0                   4.3  < 30 minutes         7.9                   98.0
# ...

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ## Content Type Distribution

# %%
df['Type'].value_counts()
# Out:
# Type
# Movie     7010
# Series    2415
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot( x='Type' ,data=df)
plt.title('Content type distribution')
plt.show()

# %%
df4['Genre'].describe()
# Out:
# count     26194
# unique       28
# top       Drama
# freq       4803
# Name: Genre, dtype: object

# %% [markdown]
# Most frequent genre of movies

# %%
df6=df4['Genre'].value_counts()

# %%
df6
# Out:
# Genre
# Drama          4803
# Comedy         3305
# Action         2149
# Thriller       2071
# Romance        1812
# Crime          1512
# Adventure      1355
# Fantasy        1228
# Animation      1173
# Sci-Fi          955
# Mystery         936
# Family          881
# Documentary     804
# Horror          717
# Biography       572
# History         449
# Music           308
# Sport           289
# War             282
# Musical         165
# Short           161
# Reality-TV      111
# Western          87
# Game-Show        32
# Talk-Show        17
# News             14
# Adult             5
# Film-Noir         1
# Name: count, dtype: int64

# %%
df7=pd.DataFrame(df6)

# %%
df7
# Out:
#              count
# Genre
# Drama         4803
# Comedy        3305
# Action        2149
# Thriller      2071
# Romance       1812
# Crime         1512
# Adventure     1355
# Fantasy       1228
# Animation     1173
# Sci-Fi         955
# Mystery        936
# Family         881
# Documentary    804
# Horror         717
# Biography      572
# History        449
# Music          308
# Sport          289
# War            282
# Musical        165
# Short          161
# Reality-TV     111
# Western         87
# Game-Show       32
# Talk-Show       17
# News            14
# Adult            5
# Film-Noir        1

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('darkgrid')
sns.barplot(x='count' , y='Genre' ,data=df7  , orient= 'h' ,width=1)
plt.title('Genre column distribution')
plt.show()

# %%
df.head()
# Out:
#                  Title                                     Genre    Type  \
# 0     Lets Fight Ghost  [Crime, Drama, Fantasy, Horror, Romance]  Series
# 1  HOW TO BUILD A GIRL                                  [Comedy]   Movie
# 2     The Con-Heartist                         [Comedy, Romance]   Movie
# 3         Gleboka woda                                   [Drama]  Series
# 4        Only a Mother                                   [Drama]   Movie
#
#    Hidden Gem Score       Runtime  IMDb Score  Rotten Tomatoes Score  \
# 0               4.3  < 30 minutes         7.9                   98.0
# 1               7.0      1-2 hour         5.8                   79.0
# 2               8.6       > 2 hrs         7.4                    NaN
# 3               8.7  < 30 minutes         7.5                    NaN
# 4               8.3      1-2 hour         6.7                    NaN
#
#    Metacritic Score  Awards Received  Awards Nominated For      Boxoffice  \
# ...

# %% [markdown]
# ## Content Rating Analysys Graphs

# %%
data1=df['Category'] = pd.cut(df['Hidden Gem Score'], bins=[0,4,6,8,10],labels = ['Bad', 'Average','Great', 'Excellent'])
data1.value_counts()
# Out:
# Hidden Gem Score
# Bad          3676
# Excellent    2425
# Great        1989
# Average      1325
# Name: count, dtype: int64

# %%
df['Category'] = pd.cut(df['Hidden Gem Score'], bins=[0,4,6,8,10],labels = ['Bad', 'Average','Great', 'Excellent'])
sns.histplot(x='Hidden Gem Score',data=df , hue='Category',bins=10 ) 
plt.ylabel('Movies & Series')
plt.title('Hidden Gem Score disribution')
plt.show()

# %%
data2=df['Category'] = pd.cut(df['IMDb Score'], bins=[3,5,6,8,10],labels = ['Bad', 'Average','Great', 'Excellent'])
data2.value_counts()
# Out:
# IMDb Score
# Great        7139
# Average      1056
# Excellent     955
# Bad           258
# Name: count, dtype: int64

# %%
df['Category'] = pd.cut(df['IMDb Score'], bins=[3,5,6,8,10],labels = ['Bad', 'Average','Great', 'Excellent'])
sns.histplot(x='IMDb Score',data=df , hue='Category',bins=10,palette='viridis') 
plt.ylabel('Movies & Series')
plt.title('IMDb Score disribution')
# Out:
# Text(0.5, 1.0, 'IMDb Score disribution')

# %%
sns.boxplot(x='Genre',y='IMDb Score',data=df5 , color='r') 
plt.ylabel('Movies & Series')
plt.title('IMDb Score disribution')
plt.xticks(rotation=90)
plt.show()

# %%
df5.head()
# Out:
#               Title    Genre    Type  Hidden Gem Score       Runtime  \
# 0  Lets Fight Ghost    Crime  Series               4.3  < 30 minutes
# 1  Lets Fight Ghost    Drama  Series               4.3  < 30 minutes
# 2  Lets Fight Ghost  Fantasy  Series               4.3  < 30 minutes
# 3  Lets Fight Ghost   Horror  Series               4.3  < 30 minutes
# 4  Lets Fight Ghost  Romance  Series               4.3  < 30 minutes
#
#    IMDb Score  Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0         7.9                   98.0              82.0             74.0
# 1         7.9                   98.0              82.0             74.0
# 2         7.9                   98.0              82.0             74.0
# 3         7.9                   98.0              82.0             74.0
# 4         7.9                   98.0              82.0             74.0
#
#    Awards Nominated For   Boxoffice Release Date  IMDb Votes
# ...

# %%
data3=df['Category'] = pd.cut(df['Metacritic Score'], bins=[30,50,70,90,100],labels = ['Bad', 'Average','Great', 'Excellent'])
data3.value_counts()
# Out:
# Metacritic Score
# Average      1739
# Bad          1057
# Great         958
# Excellent      72
# Name: count, dtype: int64

# %%
df['Category'] = pd.cut(df['Metacritic Score'], bins=[30,50,70,90,100],labels = ['Bad', 'Average','Great', 'Excellent'])
sns.histplot(x='Metacritic Score',data=df,bins=7, hue='Category', palette='RdBu' )
plt.show()

# %%
df7=df.groupby('Awards Received')['Title'].count()

# %%
df7=pd.DataFrame(df7)

# %%
df7=df7.reset_index()

# %%
df7
# Out:
#      Awards Received  Title
# 0                0.0   4199
# 1                1.0   1307
# 2                2.0    770
# 3                3.0    507
# 4                4.0    395
# ..               ...    ...
# 126            239.0      1
# 127            241.0      1
# 128            242.0      2
# 129            251.0      1
# 130            300.0      1
#
# [131 rows x 2 columns]

# %%
df7['Award Category'] = pd.cut(df7['Awards Received'], 
                               bins=[0,10, 70, 150, 200, 300], 
                               labels=['Very low','Normal', 'Average', 'Great', 'Most Awarded'])

# %%
df7_awardscount=df7['Award Category'].value_counts()

# %%
df7_awardscount=pd.DataFrame(df7_awardscount)

# %%
df7_awardscount.reset_index()
# Out:
#   Award Category  count
# 0         Normal     59
# 1        Average     44
# 2       Very low     10
# 3          Great      9
# 4   Most Awarded      8

# %%
sns.barplot(x='count',y='Award Category', data=df7_awardscount , color='g')
plt.xlabel('Movies & Series')
plt.show()

# %%
data4=df['Category'] = pd.cut(df['Rotten Tomatoes Score'], bins=[30,50,70,90,100],labels = ['Bad', 'Average','Great', 'Excellent'])
data4.value_counts()
# Out:
# Rotten Tomatoes Score
# Great        1829
# Average      1329
# Excellent     848
# Bad           700
# Name: count, dtype: int64

# %%
df['Category'] = pd.cut(df['Rotten Tomatoes Score'], bins=[30,50,70,90,100],labels = ['Bad', 'Average','Great', 'Excellent'])
sns.histplot(x='Rotten Tomatoes Score',data=df,bins=7, hue='Category' ,palette='RdYlBu')
plt.show()

# %%
df5.head()
# Out:
#               Title    Genre    Type  Hidden Gem Score       Runtime  \
# 0  Lets Fight Ghost    Crime  Series               4.3  < 30 minutes
# 1  Lets Fight Ghost    Drama  Series               4.3  < 30 minutes
# 2  Lets Fight Ghost  Fantasy  Series               4.3  < 30 minutes
# 3  Lets Fight Ghost   Horror  Series               4.3  < 30 minutes
# 4  Lets Fight Ghost  Romance  Series               4.3  < 30 minutes
#
#    IMDb Score  Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 0         7.9                   98.0              82.0             74.0
# 1         7.9                   98.0              82.0             74.0
# 2         7.9                   98.0              82.0             74.0
# 3         7.9                   98.0              82.0             74.0
# 4         7.9                   98.0              82.0             74.0
#
#    Awards Nominated For   Boxoffice Release Date  IMDb Votes
# ...

# %% [markdown]
# ## Most Awarded Genre

# %%
df8=df5.groupby('Genre')['Awards Received'].count()

# %%
df8=pd.DataFrame(df8)
df8
# Out:
#              Awards Received
# Genre
# Action                  2149
# Adult                      5
# Adventure               1355
# Animation               1173
# Biography                572
# Comedy                  3305
# Crime                   1512
# Documentary              804
# Drama                   4803
# Family                   881
# Fantasy                 1228
# Film-Noir                  1
# Game-Show                 32
# History                  449
# Horror                   717
# Music                    308
# Musical                  165
# Mystery                  936
# News                      14
# Reality-TV               111
# Romance                 1812
# Sci-Fi                   955
# Short                    161
# Sport                    289
# Talk-Show                 17
# Thriller                2071
# War                      282
# Western                   87

# %%
sns.lineplot(y='Awards Received',x='Genre' , data=df8, color='orange' , marker='o')
plt.xticks(rotation=90)
plt.show()

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26219 entries, 0 to 26218
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  26219 non-null  object
#  1   Genre                  26194 non-null  object
#  2   Type                   26219 non-null  object
#  3   Hidden Gem Score       26219 non-null  float64
#  4   Runtime                26218 non-null  object
#  5   IMDb Score             26207 non-null  float64
#  6   Rotten Tomatoes Score  15816 non-null  float64
#  7   Metacritic Score       26219 non-null  float64
#  8   Awards Received        26219 non-null  float64
#  9   Awards Nominated For   26219 non-null  float64
#  10  Boxoffice              26219 non-null  object
#  11  Release Date           25743 non-null  object
#  12  IMDb Votes             26219 non-null  float64
# dtypes: float64(7), object(6)
# memory usage: 2.6+ MB

# %% [markdown]
# ## Difrent types rating Comparison

# %%
sns.scatterplot(data=df5,x='Hidden Gem Score' ,y='IMDb Score',color='m')
plt.title('Hidden Gem VS IMDb Score')
plt.show()

# %%
df5['Rotten Tomatoes Score']=pd.to_numeric(df5['Rotten Tomatoes Score'],errors='coerce')

# %%
data6=df[df['Rotten Tomatoes Score']>40][['Rotten Tomatoes Score','IMDb Score']].sort_values(by='IMDb Score')

# %%
data6
# Out:
#       Rotten Tomatoes Score  IMDb Score
# 8654                   65.0         1.6
# 3931                   73.0         2.7
# 1308                   67.0         3.2
# 3887                   60.0         3.3
# 1246                   57.0         3.4
# ...                     ...         ...
# 4050                   80.0         NaN
# 4225                   67.0         NaN
# 4495                   83.0         NaN
# 5208                   52.0         NaN
# 8690                   94.0         NaN
#
# [4394 rows x 2 columns]

# %%
sns.scatterplot(data=df5,x='Rotten Tomatoes Score' ,y='IMDb Score',color='m')
plt.title('Rotten Tomatoes Score VS IMDb Score')
plt.show()

# %%
data5=df5[df5['Hidden Gem Score']> 8][['Hidden Gem Score','IMDb Score']].sort_values(by='IMDb Score')

# %%
data5
# Out:
#        Hidden Gem Score  IMDb Score
# 12617               8.1         4.2
# 12616               8.1         4.2
# 12615               8.1         4.2
# 12614               8.1         4.2
# 2734                8.5         4.8
# ...                 ...         ...
# 330                 9.7         9.4
# 329                 9.7         9.4
# 3448                9.6         9.5
# 450                 9.8         9.7
# 449                 9.8         9.7
#
# [5375 rows x 2 columns]

# %%
sns.scatterplot(data=data5,x='Hidden Gem Score' ,y='IMDb Score',color='b')
plt.title('Hidden Gem VS IMDb Score')
plt.show()

# %% [markdown]
# ### Most awarded movie

# %%
most_awarded=df.loc[df['Awards Received']> 30 ][['Title','Awards Received']].sort_values('Awards Received',ascending=False)

# %%
most_awarded
# Out:
#                          Title  Awards Received
# 938                   Parasite            300.0
# 3438                      ROMA            251.0
# 7710          12 Years a Slave            242.0
# 4817                La La Land            242.0
# 6319        Mad Max: Fury Road            241.0
# ...                        ...              ...
# 6912                District 9             31.0
# 3513         Operation Red Sea             31.0
# 125   American Dreams in China             31.0
# 6334                 Outlander             31.0
# 5080       I Am Not Your Negro             31.0
#
# [351 rows x 2 columns]

# %%
most_awarded=pd.DataFrame(most_awarded)

# %%
df[df['Awards Received']==df['Awards Received'].max()]
# Out:
#         Title                      Genre   Type  Hidden Gem Score  Runtime  \
# 938  Parasite  [Comedy, Drama, Thriller]  Movie               4.7  > 2 hrs
#
#      IMDb Score  Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 938         8.6                   98.0              96.0            300.0
#
#      Awards Nominated For    Boxoffice Release Date  IMDb Votes   Category
# 938                 262.0  $53,369,749  08 Nov 2019    566337.0  Excellent

# %%
most_awarded
# Out:
#                          Title  Awards Received
# 938                   Parasite            300.0
# 3438                      ROMA            251.0
# 7710          12 Years a Slave            242.0
# 4817                La La Land            242.0
# 6319        Mad Max: Fury Road            241.0
# ...                        ...              ...
# 6912                District 9             31.0
# 3513         Operation Red Sea             31.0
# 125   American Dreams in China             31.0
# 6334                 Outlander             31.0
# 5080       I Am Not Your Negro             31.0
#
# [351 rows x 2 columns]

# %% [markdown]
# ### Top 10 awarded movie or series

# %%
top_10Awarded =most_awarded.sort_values(by='Awards Received', ascending=False).head(10)

# %%
top_10Awarded
# Out:
#                                                 Title  Awards Received
# 938                                          Parasite            300.0
# 3438                                             ROMA            251.0
# 7710                                 12 Years a Slave            242.0
# 4817                                       La La Land            242.0
# 6319                               Mad Max: Fury Road            241.0
# 7508                                          Gravity            239.0
# 207                                     Sesame Street            232.0
# 5226                                        Moonlight            229.0
# 9114    The Lord of the Rings: The Return of the King            210.0
# 6951  Birdman or (The Unexpected Virtue of Ignorance)            194.0

# %%
sns.barplot(x='Title', y='Awards Received' ,data=top_10Awarded, color='g')
plt.xticks(rotation=90)
plt.title('Top 10 Awarded Movies')
plt.show()

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26219 entries, 0 to 26218
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  26219 non-null  object
#  1   Genre                  26194 non-null  object
#  2   Type                   26219 non-null  object
#  3   Hidden Gem Score       26219 non-null  float64
#  4   Runtime                26218 non-null  object
#  5   IMDb Score             26207 non-null  float64
#  6   Rotten Tomatoes Score  15816 non-null  float64
#  7   Metacritic Score       26219 non-null  float64
#  8   Awards Received        26219 non-null  float64
#  9   Awards Nominated For   26219 non-null  float64
#  10  Boxoffice              26219 non-null  object
#  11  Release Date           25743 non-null  object
#  12  IMDb Votes             26219 non-null  float64
# dtypes: float64(7), object(6)
# memory usage: 2.6+ MB

# %%
df.head()
# Out:
#                  Title                                     Genre    Type  \
# 0     Lets Fight Ghost  [Crime, Drama, Fantasy, Horror, Romance]  Series
# 1  HOW TO BUILD A GIRL                                  [Comedy]   Movie
# 2     The Con-Heartist                         [Comedy, Romance]   Movie
# 3         Gleboka woda                                   [Drama]  Series
# 4        Only a Mother                                   [Drama]   Movie
#
#    Hidden Gem Score       Runtime  IMDb Score  Rotten Tomatoes Score  \
# 0               4.3  < 30 minutes         7.9                   98.0
# 1               7.0      1-2 hour         5.8                   79.0
# 2               8.6       > 2 hrs         7.4                    NaN
# 3               8.7  < 30 minutes         7.5                    NaN
# 4               8.3      1-2 hour         6.7                    NaN
#
#    Metacritic Score  Awards Received  Awards Nominated For      Boxoffice  \
# ...

# %%
df['Boxoffice']=df['Boxoffice'].replace('Not Disclosed','0') 
df['Boxoffice']=df['Boxoffice'].replace(r'[\$,]','' ,regex=True)

# %%
df.rename(columns={'Boxoffice': 'Boxoffice($)'}, inplace=True)

# %%
df.head()
# Out:
#                  Title                                     Genre    Type  \
# 0     Lets Fight Ghost  [Crime, Drama, Fantasy, Horror, Romance]  Series
# 1  HOW TO BUILD A GIRL                                  [Comedy]   Movie
# 2     The Con-Heartist                         [Comedy, Romance]   Movie
# 3         Gleboka woda                                   [Drama]  Series
# 4        Only a Mother                                   [Drama]   Movie
#
#    Hidden Gem Score       Runtime  IMDb Score  Rotten Tomatoes Score  \
# 0               4.3  < 30 minutes         7.9                   98.0
# 1               7.0      1-2 hour         5.8                   79.0
# 2               8.6       > 2 hrs         7.4                    NaN
# 3               8.7  < 30 minutes         7.5                    NaN
# 4               8.3      1-2 hour         6.7                    NaN
#
#    Metacritic Score  Awards Received  Awards Nominated For Boxoffice($)  \
# ...

# %%
df['Boxoffice($)'] = pd.to_numeric(df['Boxoffice($)'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9425 entries, 0 to 9424
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Title                  9425 non-null   object
#  1   Genre                  9400 non-null   object
#  2   Type                   9425 non-null   object
#  3   Hidden Gem Score       9425 non-null   float64
#  4   Runtime                9424 non-null   object
#  5   IMDb Score             9417 non-null   float64
#  6   Rotten Tomatoes Score  5445 non-null   float64
#  7   Metacritic Score       9425 non-null   float64
#  8   Awards Received        9425 non-null   float64
#  9   Awards Nominated For   9425 non-null   float64
#  10  Boxoffice($)           9425 non-null   int64
#  11  Release Date           9217 non-null   object
#  12  IMDb Votes             9425 non-null   float64
#  13  Category               4706 non-null   category
# ...

# %%
df[df['Boxoffice($)'] == df['Boxoffice($)'].max()]
# Out:
#         Title             Genre   Type  Hidden Gem Score  Runtime  IMDb Score  \
# 7830  Titanic  [Drama, Romance]  Movie               4.0  > 2 hrs         7.8
#
#       Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 7830                   89.0              75.0            123.0
#
#       Awards Nominated For  Boxoffice($) Release Date  IMDb Votes Category
# 7830                  83.0     659363944  19 Dec 1997   1048704.0    Great

# %% [markdown]
# ### Highest Imdb rated Movie or Series

# %%
df[df['IMDb Score']==df['IMDb Score'].max()]
# Out:
#            Title                 Genre   Type  Hidden Gem Score   Runtime  \
# 187  No Festival  [Documentary, Music]  Movie               9.8  1-2 hour
#
#      IMDb Score  Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 187         9.7                    NaN               0.0              0.0
#
#      Awards Nominated For  Boxoffice($) Release Date  IMDb Votes Category
# 187                   0.0             0  15 Jul 2020        49.0      NaN

# %% [markdown]
# ### Highest Hidden gem Rated movie or series

# %%
df[df['Hidden Gem Score']==df['Hidden Gem Score'].max()]
# Out:
#            Title                 Genre   Type  Hidden Gem Score   Runtime  \
# 187  No Festival  [Documentary, Music]  Movie               9.8  1-2 hour
#
#      IMDb Score  Rotten Tomatoes Score  Metacritic Score  Awards Received  \
# 187         9.7                    NaN               0.0              0.0
#
#      Awards Nominated For  Boxoffice($) Release Date  IMDb Votes Category
# 187                   0.0             0  15 Jul 2020        49.0      NaN

# %% [markdown]
# ## Highest  critcs rated Movie or series

# %%
df[df['Metacritic Score']==df['Metacritic Score'].max()]
# Out:
#                                      Title  \
# 6909  Lawrence of Arabia: Restored Version
# 8210                Trois Couleurs - Rouge
# 8724                         The Godfather
#
#                                             Genre   Type  Hidden Gem Score  \
# 6909  [Adventure, Biography, Drama, History, War]  Movie               4.7
# 8210                    [Drama, Mystery, Romance]  Movie               4.7
# 8724                               [Crime, Drama]  Movie               4.8
#
#        Runtime  IMDb Score  Rotten Tomatoes Score  Metacritic Score  \
# 6909   > 2 hrs         8.3                   97.0             100.0
# 8210  1-2 hour         8.1                  100.0             100.0
# 8724   > 2 hrs         9.2                   98.0             100.0
#
#       Awards Received  Awards Nominated For  Boxoffice($) Release Date  \
# 6909             30.0                  14.0      45306425  11 Dec 1962
# ...

# %% [markdown]
# ### Top 10 highest grossing movie or series

# %%
top_10 =df.sort_values(by='Boxoffice($)', ascending=False).head(10)

# %%
top_10
# Out:
#                                Title                                 Genre  \
# 7830                         Titanic                      [Drama, Romance]
# 5695                  Jurassic World           [Action, Adventure, Sci-Fi]
# 8261               Avengers Assemble           [Action, Adventure, Sci-Fi]
# 8514                 The Dark Knight      [Action, Crime, Drama, Thriller]
# 802                   Im Leaving Now  [Action, Adventure, Fantasy, Sci-Fi]
# 1112  Id like to Borrow a Girlfriend  [Action, Adventure, Fantasy, Sci-Fi]
# 582   Im Standing on a Million Lives  [Action, Adventure, Fantasy, Sci-Fi]
# 2164  Im with the Band: Nasty Cherry  [Action, Adventure, Fantasy, Sci-Fi]
# 727                     Im losing it  [Action, Adventure, Fantasy, Sci-Fi]
# 711       Im Not Ready for Christmas  [Action, Adventure, Fantasy, Sci-Fi]
#
#         Type  Hidden Gem Score       Runtime  IMDb Score  \
# 7830   Movie               4.0       > 2 hrs         7.8
# ...

# %%
sns.barplot(x='Title', y='Boxoffice($)' ,data=top_10, color='r')
plt.xticks(rotation=90)
plt.title('Top 10 Grossing Movies')
plt.show()

# %% [markdown]
# ### Top 10 Imdb Rated movies or series

# %%
top_10IMDb =df.sort_values(by='IMDb Score', ascending=False).head(10)

# %%
top_10IMDb
# Out:
#                          Title                                   Genre  \
# 187                No Festival                    [Documentary, Music]
# 9366              Breaking Bad                [Crime, Drama, Thriller]
# 1351       Flavours of Romania                           [Documentary]
# 135            The Dream House                [Comedy, Drama, Fantasy]
# 2975                Our Planet                           [Documentary]
# 8650  The Shawshank Redemption                                 [Drama]
# 6320            Rick and Morty  [Animation, Adventure, Comedy, Sci-Fi]
# 8724             The Godfather                          [Crime, Drama]
# 3812                Conspiracy                    [Documentary, Short]
# 3806                  Im Sorry                           [Documentary]
#
#         Type  Hidden Gem Score       Runtime  IMDb Score  \
# 187    Movie               9.8      1-2 hour         9.7
# 9366  Series               4.8  < 30 minutes         9.5
# ...

# %%
sns.barplot(x='Title', y='IMDb Score' ,data=top_10IMDb, color='y')
plt.xticks(rotation=90)
plt.title('Top 10 IMDb Rated Movies')
plt.show()

# %% [markdown]
# ### Top 10 hidden Gem movies or series

# %%
top_10gem =df.sort_values(by='Hidden Gem Score', ascending=False).head(10)

# %%
top_10gem
# Out:
#                     Title                     Genre    Type  Hidden Gem Score  \
# 187           No Festival      [Documentary, Music]   Movie               9.8
# 135       The Dream House  [Comedy, Drama, Fantasy]   Movie               9.7
# 1351  Flavours of Romania             [Documentary]  Series               9.6
# 662   A Lion in the House             [Documentary]  Series               9.6
# 3806             Im Sorry             [Documentary]  Series               9.6
# 3812           Conspiracy      [Documentary, Short]   Movie               9.6
# 1460       Bye Bye London           [Comedy, Drama]   Movie               9.5
# 1053           Green Gold      [Documentary, Short]   Movie               9.5
# 3361     The Last Animals             [Documentary]   Movie               9.5
# 4000      The Consuls Son                 [Musical]   Movie               9.5
#
#            Runtime  IMDb Score  Rotten Tomatoes Score  Metacritic Score  \
# ...

# %%
sns.barplot(x='Title', y='Hidden Gem Score' ,data=top_10gem, color='g')
plt.xticks(rotation=90)
plt.title('Top 10 Hidden Gem Movies')
plt.show()

# %% [markdown]
# # Recommendation system

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# Step 1: Prepare the data
df_recommend = df.copy()

# Fill missing genres with empty strings
df_recommend['Genre'] = df_recommend['Genre'].apply(lambda x: ' '.join(x) if isinstance(x, list) else str(x))
df_recommend['Genre'] = df_recommend['Genre'].fillna('')

# Combine features into a single string
df_recommend['features'] = (
    df_recommend['Genre'] + ' ' +
    df_recommend['Type'] + ' ' +
    df_recommend['Hidden Gem Score'].astype(str) + ' ' +
    df_recommend['IMDb Score'].astype(str)
)

# Step 2: Vectorize the text using TF-IDF
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(df_recommend['features'])

# Step 3: Compute similarity scores
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# Step 4: Build a recommendation function
indices = pd.Series(df_recommend.index, index=df_recommend['Title']).drop_duplicates()

def recommend(title, num_recommendations=5):
    idx = indices.get(title)

    if idx is None:
        return "Title not found in dataset."

    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:num_recommendations+1]

    movie_indices = [i[0] for i in sim_scores]
    return df_recommend[['Title', 'Genre', 'IMDb Score']].iloc[movie_indices]
# Out:
#                             Title          Genre  IMDb Score
# 24                Floating Clouds  Drama Romance         7.7
# 25   Restart After Come Back Home  Drama Romance         7.2
# 81                           Love  Drama Romance         6.1
# 101                Story of Women  Drama Romance         7.5
# 104                 Madame Bovary  Drama Romance         5.7

# %% [markdown]
# ## recommendation examples

# %%
recommend("Avengers Assemble",5)
# Out:
#                                Title                    Genre  IMDb Score
# 2546                       Bumblebee  Action Adventure Sci-Fi         6.8
# 2981  Jurassic World: Fallen Kingdom  Action Adventure Sci-Fi         6.2
# 3021                           Venom  Action Adventure Sci-Fi         6.7
# 3097           Pacific Rim: Uprising  Action Adventure Sci-Fi         5.6
# 3251                         Rampage  Action Adventure Sci-Fi         6.1

# %%
recommend("The Godfather",5)
# Out:
#                Title        Genre  IMDb Score
# 44       The Rookies  Crime Drama         6.7
# 191  The White Tiger  Crime Drama         7.2
# 482       Blue Story  Crime Drama         6.0
# 511         Fiction.  Crime Drama         8.9
# 547         Toomelah  Crime Drama         6.2
